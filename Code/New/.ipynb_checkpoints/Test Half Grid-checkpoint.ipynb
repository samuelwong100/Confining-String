# %%
from Source import Solution_Viewer
sol_full=Solution_Viewer("CS(N=2,charge=w1,bound=x1,L=30,w=15,h=0.1,R=10,tol=1e-05,initial_kw=BPS,use_half_grid=False)")
sol_half=Solution_Viewer("CS(N=2,charge=w1,bound=x1,L=30,w=15,h=0.1,R=10,tol=1e-05,initial_kw=BPS,use_half_grid=True)")

# %%
sol_full.display_all()
# Out:
# Attributes:
# N = 2
# charge_arg = w1
# bound_arg = x1
# L = 30
# w = 15
# h = 0.1
# R = 10
# use_half_grid = False
# tolerance = 1e-05
# error = 9.995779783350155e-06
# max loop = 3952
# initial keyword = BPS
# gradient energy = 63.61981208938906
# C:\Users\samue\Documents\GitHub\Confining-String\Code\New\Source.py:89: NumbaWarning:
# Compilation is falling back to object mode WITH looplifting enabled because Function "dot_vec_with_vec_field_numba" failed type inference due to: Invalid use of Function(<built-in function zeros>) with argument(s) of type(s): (dtype=Function(<class 'complex'>), shape=UniTuple(int64 x 2))
#  * parameterized
# In definition 0:
#     All templates rejected with literals.
# In definition 1:
#     All templates rejected without literals.
# This error is usually caused by passing an argument of a type that is unsupported by the named function.
# [1] During: resolving callee type: Function(<built-in function zeros>)
# ...

# %%
sol_half.display_all()
# Out:
# Attributes:
# N = 2
# charge_arg = w1
# bound_arg = x1
# L = 30
# w = 15
# h = 0.1
# R = 10
# use_half_grid = True
# tolerance = 1e-05
# error = 9.991551446514221e-06
# max loop = 3915
# initial keyword = BPS
# gradient energy = 63.63283147377546
# potential energy = 37.695890694206675
# energy = 101.32872216798215

# %%
from Source import within_epsilon

# %%
within_epsilon(sol_full.x,sol_half.x)
# Out:
# True

# %% [markdown]
# The solution fields for half and full are exactly the same! They even pass the very stringent within_epsilon test! Hence, I finally conclude that my new half grid method is compeltely correct, the original motivation for this global rewrite project.
