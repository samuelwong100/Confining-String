# %% [markdown]
# Test how accurate half grid is.

# %%
pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from Solver import Solver, Continue_Solver

# %% [markdown]
# Half grid result

# %%
sol = Solver(N=2,charge_arg="w1",bound_arg="x1",L=20,w=15,h=0.1,R=5,max_loop=1000,x0=None,half_grid=True,diagnose=True)
# Out:
# loop = 100 error = 0.0001648857270188854
# loop = 200 error = 6.58681332702369e-05
# loop = 300 error = 3.286386884929651e-05
# loop = 400 error = 1.8120778761907377e-05
# loop = 500 error = 1.0499870171875943e-05
# loop = 600 error = 6.244067098850822e-06
# loop = 700 error = 3.771632858656898e-06
# loop = 800 error = 2.3083661291738963e-06
# loop = 900 error = 1.435275822536645e-06
# loop = 1000 error = 9.189992197651579e-07
# Attributes:
# N = 2
# charge_arg = w1
# bound_arg = x1
# max loop = 1000
# L = 20
# w = 15
# h = 0.1
# R = 5
# loop = 1000
# error = 9.189992197651579e-07
# energy = 61.61431955840045

# %%
sol = Continue_Solver(old_title="CS(N=2,charge=w1,bound=x1,L=20,w=15,h=0.1,R=5,max_loop=1000,x0=None)",max_loop=3000,diagnose=True,half_grid=True)
# Out:
# loop = 1100 error = 6.289524716173519e-07
# loop = 1200 error = 5.004437372830554e-07
# loop = 1300 error = 4.367395081571866e-07
# loop = 1400 error = 3.8256872975027114e-07
# loop = 1500 error = 3.3478534384920505e-07
# loop = 1600 error = 2.927339864699128e-07
# loop = 1700 error = 2.5581943629403583e-07
# loop = 1800 error = 2.234710893335425e-07
# loop = 1900 error = 1.9515878867479206e-07
# loop = 2000 error = 1.7040013757074571e-07
# loop = 2100 error = 1.4876204669026226e-07
# loop = 2200 error = 1.298591316127834e-07
# loop = 2300 error = 1.1335050699061896e-07
# loop = 2400 error = 9.893588117623845e-08
# loop = 2500 error = 8.635146844488314e-08
# loop = 2600 error = 7.536600480846737e-08
# loop = 2700 error = 6.577701501249237e-08
# loop = 2800 error = 5.740739773237117e-08
# loop = 2900 error = 5.010234907158369e-08
# loop = 3000 error = 4.3726618457278395e-08
# Attributes:
# N = 2
# charge_arg = w1
# bound_arg = x1
# max loop = 3000
# L = 20
# w = 15
# h = 0.1
# R = 5
# ...

# %% [markdown]
# Full grid result

# %%
sol = Solver(N=2,charge_arg="w1",bound_arg="x1",L=20,w=15,h=0.1,R=5,max_loop=3000,x0=None,half_grid=False,diagnose=True)
# Out:
# loop = 100 error = 0.00016178563357930505
# loop = 200 error = 6.436392537071149e-05
# loop = 300 error = 3.206461954238511e-05
# loop = 400 error = 1.7702084071706615e-05
# loop = 500 error = 1.0286129110700925e-05
# loop = 600 error = 6.139004042681645e-06
# loop = 700 error = 3.7228785338569076e-06
# loop = 800 error = 2.287825060589399e-06
# loop = 900 error = 1.427790171144185e-06
# loop = 1000 error = 9.166217156985466e-07
# loop = 1100 error = 6.271489857419511e-07
# loop = 1200 error = 4.981122376514325e-07
# loop = 1300 error = 4.354654750078013e-07
# loop = 1400 error = 3.8228719607665226e-07
# loop = 1500 error = 3.352778661521824e-07
# loop = 1600 error = 2.938117340635658e-07
# loop = 1700 error = 2.573271972795323e-07
# loop = 1800 error = 2.2528290772349478e-07
# loop = 1900 error = 1.9717345306289187e-07
# loop = 2000 error = 1.725371239842487e-07
# loop = 2100 error = 1.5095798146409118e-07
# loop = 2200 error = 1.320647650720009e-07
# ...

# %% [markdown]
# Desipte a small difference in the energy, the overall solution is entirely the same. I conclude that there is nothing to worry about in the half grid method.
