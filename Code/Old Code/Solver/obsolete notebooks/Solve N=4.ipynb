# %%
pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from Solver import Solver
import time
start = time.time()
sol = Solver(N=4,charge_arg="w1",bound_arg="x1",L=10,w=10,h=0.1,R=5,max_loop=400,
             x0="BPS",half_grid=True,diagnose=True)
end = time.time()
print(end - start)
# Out:
# 38.366347312927246

# %%
sol.display_all()
# Out:
# Attributes:
# N = 4
# charge_arg = w1
# bound_arg = x1
# max loop = 400
# L = 10
# w = 10
# h = 0.1
# R = 5
# loop = 400
# error = 0.00032881198259631386
# energy = 102.07688295442823
