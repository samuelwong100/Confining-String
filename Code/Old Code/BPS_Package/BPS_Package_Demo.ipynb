# %% [markdown]
# Reminder of how to use the BPS package to solve 1D BPS equation.

# %%
from solve_BPS import solve_BPS

# %% [markdown]
# Two possible SU(2) soliton

# %%
z,x = solve_BPS(N=2,vac0_arg="w1",vacf_arg="x1",z0=-20,zf=20,h=0.1,folder="example/",tol=1e-5)

# %%
z,x = solve_BPS(N=2,vac0_arg="x0",vacf_arg="x1",z0=-20,zf=20,h=0.1,folder="example/",tol=1e-5)

# %% [markdown]
# Anti-kink of the above

# %%
z,x = solve_BPS(N=2,vac0_arg="x1",vacf_arg="x0",z0=-20,zf=20,h=0.1,folder="example/",tol=1e-5)

# %% [markdown]
# Simplest SU(3) case

# %%
z,x = solve_BPS(N=3,vac0_arg="x0",vacf_arg="x1",z0=-20,zf=20,h=0.1,folder="example/",tol=1e-5)
