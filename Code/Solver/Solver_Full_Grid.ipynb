# %%
from Solver_Full_Grid import Solver_Full_Grid

# %%
Solver_Full_Grid(N=3,charge_arg="w1",bound_arg="x0",L=5,w=5,h=0.05,R=1,tol=1e-30,max_loop=500,x0=None,diagnose=True)
# Out:
# Attributes:
# N = 3
# charge_arg = w1
# bound_arg = x0
# max loop = 500
# tolerance = 1e-30
# L = 5
# w = 5
# h = 0.05
# R = 1
# loop = 501
# error = 3.5866756092696284e-05
# energy = 37.64309753286643

# %%
file="../Results/Solutions/CS(N=3,charge=w1,bound=x0,L=5,w=5,h=0.05,R=1,tol=1e-30,max_loop=500,x0=None,method=full grid)/core_dict"

# %%
import pickle
with open(file,"rb") as file:
    core_dict = pickle.load(file)

# %%
core_dict["N"]
# Out:
# 3

# %%
core_dict["energy"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-25-4551e175b482> in <module>()
# ----> 1 core_dict["energy"]
#
# KeyError: 'energy'
