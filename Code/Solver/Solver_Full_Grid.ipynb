# %%
from Solver_Full_Grid import Solver_Full_Grid

# %%
Solver_Full_Grid(N=3,charge_arg="w1",bound_arg="x0",L=3,w=3,h=0.1,R=1,tol=1e-20,max_loop=500,x0=None,diagnose=True)
# Out:
# loop = 50 error = 0.0011975519615850686
# loop = 100 error = 0.00021913985811728516
# loop = 150 error = 4.515639208137434e-05
# loop = 200 error = 1.4451735688467106e-05
# loop = 250 error = 7.345258979277265e-06
# loop = 300 error = 3.814552704623322e-06
# loop = 350 error = 1.9733750019938863e-06
# loop = 400 error = 1.0190634204172169e-06
# loop = 450 error = 5.258611762870333e-07
# loop = 500 error = 2.712749862460581e-07
# Attributes:
# N = 3
# charge_arg = w1
# bound_arg = x0
# max loop = 500
# tolerance = 1e-20
# L = 3
# w = 3
# h = 0.1
# R = 1
# loop = 501
# error = 2.677070604481923e-07
# energy = 33.96377620373103
