# %%
from Solver_Full_Grid import Solver_Full_Grid

# %%
sol = Solver_Full_Grid(N=2,charge_arg="w1",bound_arg="x0",L=10,w=10,h=0.1,R=5,tol=1e-30,max_loop=1000,x0="BPS",diagnose=True)
# Out:
# loop = 50 error = 0.0009372444633665314
# loop = 100 error = 0.000650383501362927
# loop = 150 error = 0.00059626625491313
# loop = 200 error = 0.0005544969762442508
# loop = 250 error = 0.0005111365188276691
# loop = 300 error = 0.0004707340252885813
# loop = 350 error = 0.00043383719887969024
# loop = 400 error = 0.00039964740006043003
# loop = 450 error = 0.0003672636297919799
# loop = 500 error = 0.00033602587761594714
# loop = 550 error = 0.0003055600742488947
# loop = 600 error = 0.00027573780575696995
# loop = 650 error = 0.0002466205169830381
# loop = 700 error = 0.00021840544153341453
# loop = 750 error = 0.00019137463188438064
# loop = 800 error = 0.00016584569240894474
# loop = 850 error = 0.0001421248403214731
# loop = 900 error = 0.00012046587854788553
# loop = 950 error = 0.00010104002748448957
# loop = 1000 error = 8.392062755695357e-05
# Attributes:
# N = 2
# charge_arg = w1
# bound_arg = x0
# max loop = 1000
# tolerance = 1e-30
# L = 10
# w = 10
# h = 0.1
# R = 5
# ...

# %%
import numpy as np

# %%
np.max(np.imag(sol.x))
# Out:
# 2.1928415408084065

# %%
np.min(np.imag(sol.x))
# Out:
# -2.1904930684874104
