# %%
from Solver_Full_Grid import Solver_Full_Grid

# %%
sol = Solver_Full_Grid(N=2,charge_arg="w1",bound_arg="x0",L=10,w=10,h=0.1,R=5,tol=1e-30,max_loop=500,x0="BPS",diagnose=True)
# Out:
# loop = 50 error = 0.0009372444633665314
# loop = 100 error = 0.000650383501362927
# loop = 150 error = 0.00059626625491313
# loop = 200 error = 0.0005544969762442508
# loop = 250 error = 0.0005111365188276691
# loop = 300 error = 0.0004707340252885813
# loop = 350 error = 0.00043383719887969024
# loop = 400 error = 0.00039964740006043003
# loop = 450 error = 0.0003672636297919799
# loop = 500 error = 0.00033602587761594714
# Attributes:
# N = 2
# charge_arg = w1
# bound_arg = x0
# max loop = 500
# tolerance = 1e-30
# L = 10
# w = 10
# h = 0.1
# R = 5
# loop = 501
# error = 0.0003354097953114388
# energy = 65.91589294534535
