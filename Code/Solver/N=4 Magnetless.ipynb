# %%
(365.8-285.9)/5
# Out:
# 15.980000000000008

# %%
(447.7-365.8)/5
# Out:
# 16.379999999999995

# %%
4*np.sqrt(2*(1-np.cos(2*np.pi*2/4)))
# Out:
# 8.0

# %%
import numpy as np
from Solution_Viewer import Solution_Viewer
from matplotlib import pyplot as plt

# %%
sol = Solution_Viewer("CS(N=4,charge=w1 -w2 +w3,bound=x2,L=30,w=30,h=0.1,R=15,max_loop=5000,x0=BPS)")
sol.display_all()
# Out:
# Attributes:
# N = 4
# charge_arg = w1 -w2 +w3
# bound_arg = x2
# max loop = 5000
# L = 30
# w = 30
# h = 0.1
# R = 15
# loop = 5000
# error = 3.7515253347918724e-07
# energy = 285.92995565319575

# %%
plt.figure(figsize=(20,10))
plt.subplot(321)
plt.pcolormesh(sol.grid.zv,sol.grid.yv,sol.get_phi_n(0),vmax=1)
plt.title(r"$\phi_1$")
plt.colorbar()
plt.subplot(322)
plt.pcolormesh(sol.grid.zv,sol.grid.yv,sol.get_sigma_n(0))
plt.title(r"$\sigma_1$")
plt.colorbar()
plt.subplot(323)
plt.pcolormesh(sol.grid.zv,sol.grid.yv,sol.get_phi_n(1),vmax=1)
plt.colorbar()
plt.title(r"$\phi_2$")
plt.subplot(324)
plt.pcolormesh(sol.grid.zv,sol.grid.yv,sol.get_sigma_n(1))
plt.colorbar()
plt.title(r"$\sigma_2$")
plt.subplot(325)
plt.pcolormesh(sol.grid.zv,sol.grid.yv,sol.get_phi_n(2),vmax=1)
plt.colorbar()
plt.title(r"$\phi_3$")
plt.subplot(326)
plt.pcolormesh(sol.grid.zv,sol.grid.yv,sol.get_sigma_n(2))
plt.colorbar()
plt.title(r"$\sigma_3$")
plt.suptitle("N=4 Mangetless Double String")
plt.savefig("N=4 Mangetless Double String.png")
plt.show()
