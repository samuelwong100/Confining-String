# %%
pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from Solver import Solver

# %%
sol = Solver(N=2,charge_arg="w1",bound_arg="x1",L=30,w=30,h=0.1,R=5,max_loop=2000,x0="BPS",half_grid=True,diagnose=True)
# Out:
# height =  0.5384772542096538
# zf =  0
# z0 =  -15.0
# zf-z0 = 15.0
# ratio =  0.03589848361397692
# height =  0.5384772542096538
# zf =  0
# z0 =  -15.0
# zf-z0 = 15.0
# ratio =  0.03589848361397692
# loop = 100 error = 5.1937169058444226e-05
# loop = 200 error = 4.0511354986350806e-05
# loop = 300 error = 3.10609033506459e-05
# loop = 400 error = 2.3632217333718872e-05
# loop = 500 error = 1.7461094074389034e-05
# loop = 600 error = 1.2405577633532276e-05
# loop = 700 error = 8.480422371239937e-06
# loop = 800 error = 5.612444634450747e-06
# loop = 900 error = 3.6249548493072295e-06
# loop = 1000 error = 2.3031527699735736e-06
# loop = 1100 error = 1.4494821324864885e-06
# loop = 1200 error = 9.081569627779827e-07
# loop = 1300 error = 5.709585029879826e-07
# loop = 1400 error = 3.6416600310342094e-07
# loop = 1500 error = 2.417163661793657e-07
# loop = 1600 error = 1.7833633885098732e-07
# loop = 1700 error = 1.521057863201006e-07
# loop = 1800 error = 1.3211672941829646e-07
# ...
